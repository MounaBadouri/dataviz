# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('trump_tweets.csv')

# %%
df.head(20)
# Out:
#                                                source  \
# 0                                  Twitter for iPhone
# 1                                  Twitter for iPhone
# 2                                  Twitter for iPhone
# 3                                  Twitter for iPhone
# 4                                  Twitter for iPhone
# 5                                  Twitter for iPhone
# 6                                  Twitter for iPhone
# 7                                  Twitter for iPhone
# 8   Twitter for iPhone,People were screaming STOP ...
# 9   Twitter for iPhone,....Bad things took place d...
# 10                                 Twitter for iPhone
# 11                                 Twitter for iPhone
# 12                                 Twitter for iPhone
# 13                                 Twitter for iPhone
# 14                                 Twitter for iPhone
# 15                                 Twitter for iPhone
# ...

# %%
df.isnull().sum()
# Out:
# source                0
# text              17481
# created_at        17484
# retweet_count     17484
# favorite_count    17484
# is_retweet        17530
# id_str            17487
# dtype: int64

# %%
df.dtypes
# Out:
# source             object
# text               object
# created_at         object
# retweet_count     float64
# favorite_count     object
# is_retweet         object
# id_str            float64
# dtype: object

# %%
df = df.dropna(how = 'any')

# %%
df.shape
# Out:
# (37586, 7)

# %%
df = df[df['is_retweet'] == 'false']

# %%
df = df[df['favorite_count'] != 0]

# %%
df.head()
# Out:
#                source                                               text  \
# 0  Twitter for iPhone  71000000 Legal Votes. The most EVER for a sitt...
# 1  Twitter for iPhone  THE OBSERVERS WERE NOT ALLOWED INTO THE COUNTI...
# 2  Twitter for iPhone                      I WON THIS ELECTION BY A LOT!
# 3  Twitter for iPhone  Georgia Counties Using Same Software as Michig...
# 4  Twitter for iPhone  Lawyer’s Press Conference at Four Season’s Lan...
#
#             created_at  retweet_count favorite_count is_retweet        id_str
# 0  11-07-2020 21:54:48       112219.0         614411      false  1.325195e+18
# 1  11-07-2020 21:53:34        92429.0         457831      false  1.325195e+18
# 2  11-07-2020 15:36:36       175473.0        1051231      false  1.325100e+18
# 3  11-07-2020 15:23:00        68638.0         251205      false  1.325096e+18
# 4  11-07-2020 15:00:27         6191.0          25293      false  1.325091e+18

# %%
df.shape
# Out:
# (35223, 7)

# %%
df.head(20)
# Out:
#                 source                                               text  \
# 0   Twitter for iPhone  71000000 Legal Votes. The most EVER for a sitt...
# 1   Twitter for iPhone  THE OBSERVERS WERE NOT ALLOWED INTO THE COUNTI...
# 2   Twitter for iPhone                      I WON THIS ELECTION BY A LOT!
# 3   Twitter for iPhone  Georgia Counties Using Same Software as Michig...
# 4   Twitter for iPhone  Lawyer’s Press Conference at Four Season’s Lan...
# 5   Twitter for iPhone  Big press conference today in Philadelphia at ...
# 6   Twitter for iPhone  Four Season’s Landscaping! https://t.co/kZ6xTF...
# 7   Twitter for iPhone  Lawyers Press Conference at Four Seasons Phila...
# 10  Twitter for iPhone  ....This would ALSO change the Election result...
# 11  Twitter for iPhone  Tens of thousands of votes were illegally rece...
# 28  Twitter for iPhone     Incredibly stated Jim! https://t.co/FNbZ71gsZx
# 29  Twitter for iPhone  “We need an explanation as to how these number...
# ...

# %%
df = df[df['retweet_count'] != 0.0]

# %%
df = df[df['favorite_count'] != 0]

# %%
df.head(20)
# Out:
#                 source                                               text  \
# 0   Twitter for iPhone  71000000 Legal Votes. The most EVER for a sitt...
# 1   Twitter for iPhone  THE OBSERVERS WERE NOT ALLOWED INTO THE COUNTI...
# 2   Twitter for iPhone                      I WON THIS ELECTION BY A LOT!
# 3   Twitter for iPhone  Georgia Counties Using Same Software as Michig...
# 4   Twitter for iPhone  Lawyer’s Press Conference at Four Season’s Lan...
# 5   Twitter for iPhone  Big press conference today in Philadelphia at ...
# 6   Twitter for iPhone  Four Season’s Landscaping! https://t.co/kZ6xTF...
# 7   Twitter for iPhone  Lawyers Press Conference at Four Seasons Phila...
# 28  Twitter for iPhone     Incredibly stated Jim! https://t.co/FNbZ71gsZx
# 29  Twitter for iPhone  “We need an explanation as to how these number...
# 30  Twitter for iPhone  I had such a big lead in all of these states l...
# 31  Twitter for iPhone  Joe Biden should not wrongfully claim the offi...
# ...

# %%
df.shape
# Out:
# (34126, 7)

# %%
pd.unique(df['source'])
# Out:
# array(['Twitter for iPhone', 'Twitter Media Studio', 'Twitter Web App',
#        'Twitter Web Client', 'Twitter for iPad', 'Media Studio',
#        'Twitter Ads', 'Twitter for Android', 'TweetDeck', 'Instagram',
#        'Periscope', 'Twitter QandA', 'Facebook', 'Twitter for BlackBerry',
#        'Twitter for Websites', 'Twitlonger', 'Vine - Make a Scene',
#        'Mobile Web (M5)', 'TwitLonger Beta'], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
df['created_at'] = pd.to_datetime(df['created_at'])

# %%
df['favorite_count'] = pd.to_numeric(df['favorite_count'])

# %%
d = {'true': True, 'false': False}
df['is_retweet'] = df['is_retweet'].map(d)

# %%
df.dtypes
# Out:
# source                    object
# text                      object
# created_at        datetime64[ns]
# retweet_count            float64
# favorite_count             int64
# is_retweet                  bool
# id_str                   float64
# dtype: object

# %%
df.head(20)
# Out:
#                 source                                               text  \
# 0   Twitter for iPhone  71000000 Legal Votes. The most EVER for a sitt...
# 1   Twitter for iPhone  THE OBSERVERS WERE NOT ALLOWED INTO THE COUNTI...
# 2   Twitter for iPhone                      I WON THIS ELECTION BY A LOT!
# 3   Twitter for iPhone  Georgia Counties Using Same Software as Michig...
# 4   Twitter for iPhone  Lawyer’s Press Conference at Four Season’s Lan...
# 5   Twitter for iPhone  Big press conference today in Philadelphia at ...
# 6   Twitter for iPhone  Four Season’s Landscaping! https://t.co/kZ6xTF...
# 7   Twitter for iPhone  Lawyers Press Conference at Four Seasons Phila...
# 28  Twitter for iPhone     Incredibly stated Jim! https://t.co/FNbZ71gsZx
# 29  Twitter for iPhone  “We need an explanation as to how these number...
# 30  Twitter for iPhone  I had such a big lead in all of these states l...
# 31  Twitter for iPhone  Joe Biden should not wrongfully claim the offi...
# ...

# %%
df['year'] = df['created_at'].dt.year

# %%
df.head()
# Out:
#                source                                               text  \
# 0  Twitter for iPhone  71000000 Legal Votes. The most EVER for a sitt...
# 1  Twitter for iPhone  THE OBSERVERS WERE NOT ALLOWED INTO THE COUNTI...
# 2  Twitter for iPhone                      I WON THIS ELECTION BY A LOT!
# 3  Twitter for iPhone  Georgia Counties Using Same Software as Michig...
# 4  Twitter for iPhone  Lawyer’s Press Conference at Four Season’s Lan...
#
#            created_at  retweet_count  favorite_count  is_retweet  \
# 0 2020-11-07 21:54:48       112219.0          614411       False
# 1 2020-11-07 21:53:34        92429.0          457831       False
# 2 2020-11-07 15:36:36       175473.0         1051231       False
# 3 2020-11-07 15:23:00        68638.0          251205       False
# 4 2020-11-07 15:00:27         6191.0           25293       False
#
#          id_str  year
# 0  1.325195e+18  2020
# 1  1.325195e+18  2020
# 2  1.325100e+18  2020
# 3  1.325096e+18  2020
# ...

# %%
df['favorite_count'].sum()
# Out:
# 1333767315

# %%
df.groupby('year')['favorite_count'].sum()
# Out:
# year
# 2009          478
# 2010         5895
# 2011        53154
# 2012       722775
# 2013       775132
# 2014       685810
# 2015      6031234
# 2016     72443321
# 2017    150793060
# 2018    233134890
# 2019    353405604
# 2020    515715962
# Name: favorite_count, dtype: int64

# %%
df[df['year'] == 2009]
# Out:
#                    source                                               text  \
# 55063  Twitter Web Client  From Donald Trump: Wishing everyone a wonderfu...
# 55064  Twitter Web Client  Trump International Tower in Chicago ranked 6t...
# 55065  Twitter Web Client  Wishing you and yours a very Happy and Bountif...
# 55066  Twitter Web Client  Donald Trump Partners with TV1 on New Reality ...
# 55067  Twitter Web Client  --Work has begun ahead of schedule to build th...
# 55069  Twitter Web Client  Hear Donald Trump discuss big gov spending ban...
# 55070  Twitter Web Client  Watch video of Ivanka Trump sharing business a...
# 55071  Twitter Web Client  - Read what Donald Trump has to say about daug...
# 55073  Twitter Web Client  Read Donald Trump's Top Ten Tips for Success: ...
# 55075  Twitter Web Client  - Donald Trump bids to buy the Oreo Double Stu...
# 55076  Twitter Web Client  Reminder: The Miss Universe competition will b...
# ...

# %%
plt.plot(df.groupby('year')['favorite_count'].sum(), color = "darkred")
plt.xlabel('Year')
plt.ylabel('Likes')
plt.title('Number of likes per year')
# Out:
# Text(0.5, 1.0, 'Number of likes per year')

# %%
df[df['text'].str.contains('dumb')]
# Out:
#                    source                                               text  \
# 1676   Twitter for iPhone  So when will something significant happen to J...
# 3870   Twitter for iPhone  John Bolton one of the dumbest people I’ve met...
# 3963   Twitter for iPhone  Joe Biden: ‘Unlike the African American Commun...
# 5244   Twitter for iPhone  Interesting guy. “Bolton is really dumb”.  Tru...
# 6458   Twitter for iPhone  RT @realDonaldTrump: .@deanbaquet is to be ser...
# ...                   ...                                                ...
# 52860  Twitter Web Client  Some really dumb blogger for failing @VanityFa...
# 53108  Twitter Web Client  WASTE--HUD is spending $70M to teach grant rec...
# 53221  Twitter Web Client  George Will may be the dumbest(and most overra...
# 53909  Twitter Web Client  Who is the dumbest man on TV? @Lawrence of MSN...
# 53964     TwitLonger Beta  I bet the dumbest political commentator on tel...
#
# ...

# %%
df['insults'] = df['text'].str.contains('dumb')

# %%
df.head()
# Out:
#                source                                               text  \
# 0  Twitter for iPhone  71000000 Legal Votes. The most EVER for a sitt...
# 1  Twitter for iPhone  THE OBSERVERS WERE NOT ALLOWED INTO THE COUNTI...
# 2  Twitter for iPhone                      I WON THIS ELECTION BY A LOT!
# 3  Twitter for iPhone  Georgia Counties Using Same Software as Michig...
# 4  Twitter for iPhone  Lawyer’s Press Conference at Four Season’s Lan...
#
#            created_at  retweet_count  favorite_count  is_retweet  \
# 0 2020-11-07 21:54:48       112219.0          614411       False
# 1 2020-11-07 21:53:34        92429.0          457831       False
# 2 2020-11-07 15:36:36       175473.0         1051231       False
# 3 2020-11-07 15:23:00        68638.0          251205       False
# 4 2020-11-07 15:00:27         6191.0           25293       False
#
#          id_str  year  insults
# 0  1.325195e+18  2020    False
# 1  1.325195e+18  2020    False
# 2  1.325100e+18  2020    False
# ...

# %%
df.dtypes
# Out:
# source                    object
# text                      object
# created_at        datetime64[ns]
# retweet_count            float64
# favorite_count             int64
# is_retweet                  bool
# id_str                   float64
# year                       int64
# insults                     bool
# dtype: object

# %%
df['insults'].replace(to_replace = True, value = 'dumb', inplace = True)

# %%
df[df['insults'] == 'dumb']
# Out:
#                    source                                               text  \
# 1676   Twitter for iPhone  So when will something significant happen to J...
# 3870   Twitter for iPhone  John Bolton one of the dumbest people I’ve met...
# 3963   Twitter for iPhone  Joe Biden: ‘Unlike the African American Commun...
# 5244   Twitter for iPhone  Interesting guy. “Bolton is really dumb”.  Tru...
# 6458   Twitter for iPhone  RT @realDonaldTrump: .@deanbaquet is to be ser...
# ...                   ...                                                ...
# 52860  Twitter Web Client  Some really dumb blogger for failing @VanityFa...
# 53108  Twitter Web Client  WASTE--HUD is spending $70M to teach grant rec...
# 53221  Twitter Web Client  George Will may be the dumbest(and most overra...
# 53909  Twitter Web Client  Who is the dumbest man on TV? @Lawrence of MSN...
# 53964     TwitLonger Beta  I bet the dumbest political commentator on tel...
#
# ...

# %%
pd.unique(df['insults'])
# Out:
# array([False, 'dumb'], dtype=object)

# %%
df[df['text'].str.contains('loser')]
# Out:
#                    source                                               text  \
# 976    Twitter for iPhone  Steve Scully of @cspan had a very bad week. Wh...
# 1127   Twitter for iPhone  How dare failed Presidential Candidate (1% and...
# 1491   Twitter for iPhone  ...And I had to put up with these losers and s...
# 1504   Twitter for iPhone  Because I’ve beaten him and his very few remai...
# 1718   Twitter for iPhone  Nobody wants Sleepy Joe as a leader including ...
# ...                   ...                                                ...
# 53319  Twitter Web Client  .@Cher attacked @MittRomney. She is an average...
# 53349  Twitter Web Client  Firing @lisalampanelli may have come as a surp...
# 53743  Twitter Web Client  My @SquawkCNBC interview discussing why @MittR...
# 54240           TweetDeck  I feel sorry for Rosie 's new partner in love ...
# 54723           TweetDeck  The S&P are losers. They did this for personal...
#
# ...

# %%
df.loc[df['text'].str.contains('loser'), 'insults'] = 'loser'

# %%
df[df['insults'] == 'loser']
# Out:
#                    source                                               text  \
# 976    Twitter for iPhone  Steve Scully of @cspan had a very bad week. Wh...
# 1127   Twitter for iPhone  How dare failed Presidential Candidate (1% and...
# 1491   Twitter for iPhone  ...And I had to put up with these losers and s...
# 1504   Twitter for iPhone  Because I’ve beaten him and his very few remai...
# 1718   Twitter for iPhone  Nobody wants Sleepy Joe as a leader including ...
# ...                   ...                                                ...
# 53319  Twitter Web Client  .@Cher attacked @MittRomney. She is an average...
# 53349  Twitter Web Client  Firing @lisalampanelli may have come as a surp...
# 53743  Twitter Web Client  My @SquawkCNBC interview discussing why @MittR...
# 54240           TweetDeck  I feel sorry for Rosie 's new partner in love ...
# 54723           TweetDeck  The S&P are losers. They did this for personal...
#
# ...

# %%
pd.unique(df['insults'])
# Out:
# array([False, 'loser', 'dumb'], dtype=object)

# %%
#df[df['text'].str.contains('dumb') & df['text'].str.contains('moron')]

# %%
df[df['text'].str.contains(' fail ')]
#loser, dumb, moron, weak, stupid, idiot, dummy, black, crazy, corrupt, mess, fail
# Out:
#                     source                                               text  \
# 1504    Twitter for iPhone  Because I’ve beaten him and his very few remai...
# 7127    Twitter for iPhone  RT @TeamTrump: President @realDonaldTrump: The...
# 8765    Twitter for iPhone  RT @GOPChairwoman: Congratulations @realDonald...
# 14239   Twitter for iPhone  Now that the Democrats and the Fake News Media...
# 16683   Twitter for iPhone  Great fun and meeting with Prime Minister @Abe...
# 17963   Twitter for iPhone  RT @Jim_Jordan: Why did @AdamSchiff fail to di...
# 19519   Twitter for iPhone  Full efforts are being made to stop the onslau...
# 21089   Twitter for iPhone  Thank you for all of the compliments on gettin...
# 21480     Twitter for iPad  I want to thank all of our friends and patriot...
# 23758   Twitter for iPhone  As I have always said let ObamaCare fail and t...
# 26138   Twitter for iPhone  HRC is using the oldest play in the Dem playbo...
# ...

# %%
df['insults'].replace(to_replace = False, value = 'none', inplace = True)

# %%
pd.unique(df['insults'])
# Out:
# array(['none', 'loser', 'dumb'], dtype=object)

# %% [markdown]
# ### Essais pour plus tard

# %%
from itertools import combinations
insults = ['loser', 'dum', 'weak', 'stupid', 'idiot', 'black', 'crazy', 'corrupt', 'mess', 'fail',
           'terrible', 'dope', 'dishonest', 'lightweight', 'pathetic', 'incompeten', 'boring', 'fool', 'haters', 'raci', 
           'clown', 'overrated', 'disgusting', 'goofy', 'no talent']
c = [i for i in combinations(insults,2)] #liste des combinaisons 2 à 2 des insultes
for i in insults:
    df.loc[df['text'].str.contains(i), 'insults'] = i

# %% [markdown]
# pd.unique(df['insults'])

# %% [markdown]
# for k in range(len(c)):
#     for a,b in c[k]:
#         df[df['text'].str.contains(a) & df['text'].str.contains(b)]

# %%
df.groupby('insults')['favorite_count'].mean()
# Out:
# insults
# black          34468.250000
# boring         28730.328125
# clown          22638.809524
# corrupt        73944.378238
# crazy          40719.644068
# disgusting     50277.826087
# dishonest      64727.598540
# dope            7251.413043
# dum            28411.833333
# fail           33727.827493
# fool           55637.122449
# goofy          17550.428571
# haters         25278.240741
# idiot          18597.285714
# incompeten     50697.795918
# lightweight    17799.574074
# loser          35040.081081
# mess           42638.522472
# no talent      42471.769231
# none           38895.840509
# overrated      18132.840000
# pathetic       47126.811594
# raci           28721.164706
# stupid         25271.323308
# terrible       49000.811159
# weak           46030.830189
# Name: favorite_count, dtype: float64

# %%
df.groupby('insults')['retweet_count'].mean()
# Out:
# insults
# black          14823.850000
# boring          7176.718750
# clown           7100.000000
# corrupt        22878.160622
# crazy          11162.237288
# disgusting     15530.043478
# dishonest      17772.569343
# dope            2468.608696
# dum             8037.684524
# fail            9425.291105
# fool           14840.448980
# goofy           5834.857143
# haters          8693.518519
# idiot           5683.857143
# incompeten     14048.081633
# lightweight     4984.666667
# loser           8767.117117
# mess           12261.691011
# no talent       9376.230769
# none           11478.741795
# overrated       6528.240000
# pathetic       11550.608696
# raci           10134.541176
# stupid          7513.368421
# terrible       12525.952790
# weak           12652.138365
# Name: retweet_count, dtype: float64

# %%
df.groupby('insults')['favorite_count'].mean().sort_values(ascending = True).plot.bar(color = "darkred")
plt.xlabel('Insults')
plt.ylabel('Likes')
plt.ylim(0,100000)
plt.title('Number of likes per category of insults')
# Out:
# Text(0.5, 1.0, 'Number of likes per category of insults')

# %%
def get_top_year(g):
    return df['year'].value_counts().idxmax()   
df.groupby('insults')['year'].apply(get_top_year)
# Out:
# 0    2020
# dtype: int64

# %%
# Out:
#                    source                                               text  \
# 5289   Twitter for iPhone  RT @BreitbartNews: President Trump's justice d...
# 23686  Twitter for iPhone  ....victory and cannot be burdened with the tr...
#
#                created_at  retweet_count  favorite_count  is_retweet  \
# 5289  2020-06-20 17:55:42         7129.0               0       False
# 23686 2017-07-26 13:08:21        43406.0          143128       False
#
#              id_str  year insults
# 5289   1.274401e+18  2020    none
# 23686  8.901971e+17  2017    none
